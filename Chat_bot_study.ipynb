# %% [markdown]
# <a href="https://colab.research.google.com/github/kimsuujeong/Chat_bot_Game/blob/main/Chat_bot_study.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
seconds_in_a_day = 24 * 60 * 60
print(seconds_in_a_day) #하루가 몇초인가
# Out:
# 86400

# %%
seconds_in_a_week = seconds_in_a_day * 7
print(seconds_in_a_week)
# Out:
# 604800

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
data = np.random.randint(-100, 100,  50) #무작위 데이터 생성 (최소, 최대,갯수)
print(data)
# Out:
# [ 84 -26  96  68 -82 -20  14  67 -60 -12   6 -47 -62  47 -96   6 -57 -85
#    8   3   0  98  93 -78  47  66 -91 -78  14 -14  13 -24 -44  38 -96   2
#  -67  -2  58  67 -94 -88 -37 -37  95 -85  68  93   2 -56]

# %%
plt.plot(data)
plt.show()
